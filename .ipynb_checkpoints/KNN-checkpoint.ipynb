# %%
import pandas as pd
import numpy as np
from sklearn import preprocessing
import operator
import math
from scipy.spatial import distance
from matplotlib import pyplot

# %%
def withSupport(x, expr, l = 1.0):
    if abs(x) <= l:
        return expr
    else:
        return 0.0

# %%
def uniform(x):
    return withSupport(x, 0.5)

# %%
def triangular(x):
    return withSupport(x, 1 - abs(x))

# %%
def epanechnikov(x):
    return withSupport(x, 0.75 * ((1 - x ** 2) ** 2))

# %%
def quartic(x):
    return withSupport(x, 15.0/16.0 * (1 - x ** 2))

# %%
def triweight(x):
    return withSupport(x, 35.0/32.0 * ((1 - x ** 2) ** 3))

# %%
def tricube(x):
    return withSupport(x, 70.0/81.0 * ((1 - abs(x) ** 3) ** 3))

# %%
def gaussian(x):
    return 1 / math.sqrt(2.0 * math.pi) * math.exp(-0.5 * (x ** 2))

# %%
def cosine(x):
    return withSupport(x, math.pi / 4.0 * math.cos(math.pi / 2.0 * x))

# %%
def logistic(x):
    return withSupport(x, 1 / (math.exp(x) + 2.0 + math.exp(-x)))

# %%
def sigmoid(x):
    return 2.0 / math.pi * 1 / (math.exp(x) + math.exp(-x))

# %%
def silverman(x):
    return 0.5 * math.exp(-x / math.sqrt(2)) * math.sin(x / math.sqrt(2.0) + math.pi / 4.0)

# %%
allKernels = {
    "logistic" : logistic, 
    "uniform" : uniform, 
    "triangular" : triangular,
    "epanechnikov" : epanechnikov,
    "quartic" : quartic, 
    "triweight" : triweight, 
    "tricube" : tricube, 
    "gaussian" : gaussian, 
    "cosine" : cosine, 
    "sigmoid" : sigmoid, 
    "silverman" : silverman,
    "id" : id
}

# %%
allDistances = {
    "manhattan" : distance.cityblock,
    "euclidian" : distance.euclidean,
}

# %%
def readNormalizedData(file):
    df = pd.read_csv(file, sep=",").drop(columns="LRS-name")
    classes = df["LRS-class"].to_numpy()
    features = preprocessing.normalize(df.drop(columns="LRS-class").to_numpy())
    objects = []
    for i in range(len(classes)):
        objects.append({'class' : classes[i], 'vector': features[i]})
    return objects

# %%
def splitData(objects, l):
    n = max(objects, key=lambda obj: obj['class'])['class'] + 1
    
    cnt = [0 for i in range(n)]
    for obj in objects:
        cnt[obj['class']] += 1
    pyplot.plot(range(n), cnt)
    pyplot.show()
    
    train = []
    test = []
    for i in range(len(objects)):
        if i % l != l - 1:
            train.append(objects[i])
        else:
            test.append(objects[i])
    return train, test, n

# %%
def getData(file):
    return splitData(readNormalizedData(file), 5)

# %%
def kNN(newVector, n, objects, h, kernel, dist):
    votes = [0.0 for i in range(n)]
    for obj in objects:
        c = obj['class']
        v = obj['vector']
        votes[c] += kernel(dist(newVector, v) / h)
    return np.argmax(votes)

# %%
def varKNN(newVector, n, objects, k, kernel, dist):
    votes = [0.0 for i in range(n)]
    objects2 = sorted(objects, key = lambda obj: dist(newVector, obj['vector']))
    distK = dist(newVector, objects2[int(k)]['vector'])
    for obj in objects:
        c = obj['class']
        v = obj['vector']
        votes[c] += kernel(dist(newVector, v) / distK)
    return np.argmax(votes)

# %%
def calcF(precision, recall):
    if precision != 0.0 or recall != 0.0:
        return 2.0 * precision * recall / (precision + recall)
    else:
        return 0.0

def fMeasure(cnt, n):
    selectedAndRelevant = [cnt[c][c] for c in range(n)]
    selected =  [sum([cnt[i][c] for i in range(n)]) for c in range(n)]
    relevant =  [sum(cnt[c]) for c in range(n)]
    precision =  [(selectedAndRelevant[c] / selected[c] if selected[c] != 0 else 0.0) for c in range(n)]
    recall =  [(selectedAndRelevant[c] / relevant[c] if relevant[c] != 0 else 0.0) for c in range(n)]
    f = [calcF(precision[c], recall[c]) for c in range(n)]
 
    total = sum([sum(row) for row in cnt])
    weightedF = sum([f[c] * relevant[c] for c in range(n)]) / total
    weightedPrecision = sum([precision[c] * relevant[c] for c in range(n)]) / total
    weightedRecall = sum([recall[c] * relevant[c] for c in range(n)]) / total

    return calcF(weightedPrecision, weightedRecall)

# %%
def testAlgo(test, n, classifier):
    cnt = [[0.0 for i in range(n)] for j in range(n)]
    for t in test:
        c = classifier(t['vector'])
        cnt[t['class']][c] += 1.0
    return fMeasure(cnt, n)

# %%
train, test, n = getData('kNN/spectrometer.csv')
print("train size:", len(train), "\ntest size:", len(test), "\nclasses:", n,"\nfeatures:",  len(train[0]['vector']))
# Out:
# train size: 425
# test size: 106
# classes: 97
# features: 101

# %%
classifier = lambda v: kNN(v, n, train, 10.0, uniform, distance.cityblock)
f = testAlgo(test, n, classifier)
print(f)
# Out:
# 0.006064690026954178

# %%
def gridSearch(f, l, r, eps):
    if abs(r - l) < eps:
        return [], l, -1e100
    res = []
    bestX, best = l, -1e100
    for x in [l + i / 10 * (r - l) for i in range(11)]:
        y = f(x)
        res.append({'x': x, 'y' : y})
        if y > best:
            bestX = x
            best = y
    res2, newBestX, newBest = gridSearch(f, max(l, bestX - (r - l) / 10), min(r, bestX + (r - l) / 10), eps)
    if newBest > best:
        best = newBest
        bestX = newBestX
    return res + res2, bestX, best

# %%
for kernelName in allKernels:
    kernel = allKernels[kernelName]
    for distName in allDistances:
        dist = allDistances[distName]
        
        f = lambda h: testAlgo(test, n, lambda v: kNN(v, n, train, h, kernel, dist))
        res, bestH, f = gridSearch(f, 0.01, 2.0, 0.05)
        
        xs = []
        ys = []
        for obj in sorted(res, key = lambda obj : obj['x']):
            xs.append(obj['x'])
            ys.append(obj['y'])
        
        print(distName, kernelName, "h = ", bestH, "f = ", f,'\n')
        
        pyplot.plot(xs, ys)
        pyplot.show()
# Out:
# manhattan uniform h =  0.43188 f =  0.4984036784105847
# euclidian uniform h =  0.06572 f =  0.49991473369473133
# manhattan triangular h =  0.6547599999999999 f =  0.5139654861506696
# euclidian triangular h =  0.06572000000000001 f =  0.5353927689921366
# manhattan epanechnikov h =  0.8856 f =  0.5244403837368662
# euclidian epanechnikov h =  0.06572000000000001 f =  0.5357145308414037
# manhattan quartic h =  0.65476 f =  0.5060146831211221
# euclidian quartic h =  0.06572000000000001 f =  0.5353927689921366
# manhattan triweight h =  0.77416 f =  0.5263143788294463
# euclidian triweight h =  0.07368000000000001 f =  0.5429327035856916
# manhattan tricube h =  0.8458000000000001 f =  0.5251459795404029
# euclidian tricube h =  0.07368000000000001 f =  0.5360102169583264
# manhattan gaussian h =  0.15328000000000003 f =  0.5795280067928256
# euclidian gaussian h =  0.01 f =  0.5480223894428587
# manhattan cosine h =  0.6547599999999999 f =  0.5060146831211221
# euclidian cosine h =  0.06572000000000001 f =  0.5353927689921366
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# <ipython-input-384-3d19eb4ee97e> in <module>
#       5
#       6         f = lambda h: testAlgo(test, n, lambda v: kNN(v, n, train, h, kernel, dist))
# ----> 7         res, bestH, f = gridSearch(f, 0.01, 2.0, 0.05)
#       8
#       9         xs = []
#
# <ipython-input-378-3cd0652567bc> in gridSearch(f, l, r, eps)
#       5     bestX, best = l, -1e100
#       6     for x in [l + i / 10 * (r - l) for i in range(11)]:
# ----> 7         y = f(x)
#       8         res.append({'x': x, 'y' : y})
#       9         if y > best:
#
# <ipython-input-384-3d19eb4ee97e> in <lambda>(h)
#       4         dist = allDistances[distName]
#       5
# ----> 6         f = lambda h: testAlgo(test, n, lambda v: kNN(v, n, train, h, kernel, dist))
#       7         res, bestH, f = gridSearch(f, 0.01, 2.0, 0.05)
#       8
#
# <ipython-input-375-721a0db99314> in testAlgo(test, n, classifier)
#       2     cnt = [[0.0 for i in range(n)] for j in range(n)]
#       3     for t in test:
# ----> 4         c = classifier(t['vector'])
#       5         cnt[t['class']][c] += 1.0
#       6     return fMeasure(cnt, n)
#
# <ipython-input-384-3d19eb4ee97e> in <lambda>(v)
#       4         dist = allDistances[distName]
#       5
# ----> 6         f = lambda h: testAlgo(test, n, lambda v: kNN(v, n, train, h, kernel, dist))
#       7         res, bestH, f = gridSearch(f, 0.01, 2.0, 0.05)
#       8
#
# <ipython-input-373-90e71ad2513d> in kNN(newVector, n, objects, h, kernel, dist)
#       4         c = obj['class']
#       5         v = obj['vector']
# ----> 6         votes[c] += kernel(dist(newVector, v) / h)
#       7     return np.argmax(votes)
#
# <ipython-input-365-308359cae846> in logistic(x)
#       1 def logistic(x):
# ----> 2     return 1 / (math.exp(x) + 2.0 + math.exp(-x))
#
# OverflowError: math range error

# %%
for kernelName in allKernels:
    kernel = allKernels[kernelName]
    for distName in allDistances:
        dist = allDistances[distName]
        
        f = lambda k: testAlgo(test, n, lambda v: varKNN(v, n, train, k, kernel, dist))
        res, bestH, f = gridSearch(f, 1, n, 1)
        
        xs = []
        ys = []
        for obj in sorted(res, key = lambda obj : obj['x']):
            xs.append(obj['x'])
            ys.append(obj['y'])
        
        print(distName, kernelName, "k = ", bestH, "f = ", f,'\n')
        
        pyplot.plot(xs, ys)
        pyplot.show()
# Out:
# manhattan uniform k =  4.84 f =  0.5378318577535147
# euclidian uniform k =  1.0 f =  0.5855353382295425
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-391-57003704ab52> in <module>
#       5
#       6         f = lambda k: testAlgo(test, n, lambda v: varKNN(v, n, train, k, kernel, dist))
# ----> 7         res, bestH, f = gridSearch(f, 1, n, 1)
#       8
#       9         xs = []
#
# <ipython-input-378-3cd0652567bc> in gridSearch(f, l, r, eps)
#      10             bestX = x
#      11             best = y
# ---> 12     res2, newBestX, newBest = gridSearch(f, max(l, bestX - (r - l) / 10), min(r, bestX + (r - l) / 10), eps)
#      13     if newBest > best:
#      14         best = newBest
#
# <ipython-input-378-3cd0652567bc> in gridSearch(f, l, r, eps)
#       5     bestX, best = l, -1e100
#       6     for x in [l + i / 10 * (r - l) for i in range(11)]:
# ----> 7         y = f(x)
#       8         res.append({'x': x, 'y' : y})
#       9         if y > best:
#
# <ipython-input-391-57003704ab52> in <lambda>(k)
#       4         dist = allDistances[distName]
#       5
# ----> 6         f = lambda k: testAlgo(test, n, lambda v: varKNN(v, n, train, k, kernel, dist))
#       7         res, bestH, f = gridSearch(f, 1, n, 1)
#       8
#
# <ipython-input-375-721a0db99314> in testAlgo(test, n, classifier)
#       2     cnt = [[0.0 for i in range(n)] for j in range(n)]
#       3     for t in test:
# ----> 4         c = classifier(t['vector'])
#       5         cnt[t['class']][c] += 1.0
#       6     return fMeasure(cnt, n)
#
# <ipython-input-391-57003704ab52> in <lambda>(v)
#       4         dist = allDistances[distName]
#       5
# ----> 6         f = lambda k: testAlgo(test, n, lambda v: varKNN(v, n, train, k, kernel, dist))
#       7         res, bestH, f = gridSearch(f, 1, n, 1)
#       8
#
# <ipython-input-390-232cbae3dfdd> in varKNN(newVector, n, objects, k, kernel, dist)
#       1 def varKNN(newVector, n, objects, k, kernel, dist):
#       2     votes = [0.0 for i in range(n)]
# ----> 3     objects2 = sorted(objects, key = lambda obj: dist(newVector, obj['vector']))
#       4     distK = dist(newVector, objects2[int(k)]['vector'])
#       5     for obj in objects:
#
# <ipython-input-390-232cbae3dfdd> in <lambda>(obj)
#       1 def varKNN(newVector, n, objects, k, kernel, dist):
#       2     votes = [0.0 for i in range(n)]
# ----> 3     objects2 = sorted(objects, key = lambda obj: dist(newVector, obj['vector']))
#       4     distK = dist(newVector, objects2[int(k)]['vector'])
#       5     for obj in objects:
#
# /usr/local/lib/python3.7/site-packages/scipy/spatial/distance.py in cityblock(u, v, w)
#    1029
#    1030     """
# -> 1031     u = _validate_vector(u)
#    1032     v = _validate_vector(v)
#    1033     l1_diff = abs(u - v)
#
# /usr/local/lib/python3.7/site-packages/scipy/spatial/distance.py in _validate_vector(u, dtype)
#     332 def _validate_vector(u, dtype=None):
#     333     # XXX Is order='c' really necessary?
# --> 334     u = np.asarray(u, dtype=dtype, order='c').squeeze()
#     335     # Ensure values such as u=1 and u=[1] still return 1-D arrays.
#     336     u = np.atleast_1d(u)
#
# /usr/local/lib/python3.7/site-packages/numpy/core/numeric.py in asarray(a, dtype, order)
#     536
#     537     """
# --> 538     return array(a, dtype, copy=False, order=order)
#     539
#     540
#
# KeyboardInterrupt:

# %%
for kernelName in allKernels:
    kernel = allKernels[kernelName]
    for distName in allDistances:
        dist = allDistances[distName]
        
        f = lambda h: testAlgo(test, n, lambda v: kNN(v, n, train, h, kernel, dist))
        res, bestH, f = gridSearch(f, 0.01, 2.0, 0.05)
        
        xs = []
        ys = []
        for obj in sorted(res, key = lambda obj : obj['x']):
            xs.append(obj['x'])
            ys.append(obj['y'])
        
        print(distName, kernelName, "h = ", bestH, "f = ", f,'\n')
        
        pyplot.plot(xs, ys)
        pyplot.show()
# Out:
# 307.9817418591193
# 626.4464852498862
# 691.1569190271966
# 185.1762911860307
# 153.09439463965896
# 99.11682548956566
# 284.8094077934484
# 196.2164133981388
# 58.99267519868882
# 189.461744207461
# 57.076167351203544
# 168.11309778893326
# 239.5470331598361
# 58.43333784276371
# 180.51520786689062
# 72.21816369741433
# 135.93300113750485
# 98.0694980887512
# 144.50878766777777
# 202.46638234473346
# 183.63075253733834
# 50.198784906791495
# 215.5536728601949
# 213.56913133490295
# 71.92810074692547
# 302.47264330565747
# 102.04819980373225
# 155.33141572944461
# 217.99219165843286
# 138.3859933287312
# 48.07249162342847
# 155.3334328586964
# 63.765154600441264
# 210.15416931304767
# 69.35740298225925
# 288.11150614855654
# 218.71132493434118
# 149.4544413831302
# 178.9688188294307
# 76.4070993523388
# 56.177308004037684
# 203.85466023300998
# 256.9888058461522
# 424.4174450660078
# 324.29835477525734
# 77.06723120387676
# 209.02449352965684
# 197.45876547542977
# 151.54127804200138
# 206.74369535617686
# 295.7316482031363
# 269.1852111112976
# 212.54978124660062
# 640.0976213636246
# 413.25016895505513
# 255.42923715890535
# 141.49074702112887
# 100.55885742648502
# 74.58341707603218
# 95.5453902793436
# 150.82129845153614
# 220.23657414272355
# 82.51977914355349
# 100.12768916924803
# 207.50740741202404
# 171.779569928002
# 234.8324113364459
# 46.39956310647623
# 192.9420792138339
# 77.47298247713053
# 421.2515134837182
# 182.65818402709334
# 158.70670057105102
# 158.6033960231019
# 195.1895144770448
# 68.21311717624648
# 115.86328277775432
# 193.02885241274197
# 283.36612961254315
# 61.619498149539666
# 97.39445219663631
# 90.22556453088714
# 120.37583786319409
# 53.36104294527099
# 116.8043561675092
# 261.60535654410063
# 214.56732269384355
# 249.07812683288068
# 264.1464128521697
# 784.4467915657712
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# <ipython-input-411-3d19eb4ee97e> in <module>
#       5
#       6         f = lambda h: testAlgo(test, n, lambda v: kNN(v, n, train, h, kernel, dist))
# ----> 7         res, bestH, f = gridSearch(f, 0.01, 2.0, 0.05)
#       8
#       9         xs = []
#
# <ipython-input-410-3cd0652567bc> in gridSearch(f, l, r, eps)
#       5     bestX, best = l, -1e100
#       6     for x in [l + i / 10 * (r - l) for i in range(11)]:
# ----> 7         y = f(x)
#       8         res.append({'x': x, 'y' : y})
#       9         if y > best:
#
# <ipython-input-411-3d19eb4ee97e> in <lambda>(h)
#       4         dist = allDistances[distName]
#       5
# ----> 6         f = lambda h: testAlgo(test, n, lambda v: kNN(v, n, train, h, kernel, dist))
#       7         res, bestH, f = gridSearch(f, 0.01, 2.0, 0.05)
#       8
#
# <ipython-input-407-721a0db99314> in testAlgo(test, n, classifier)
#       2     cnt = [[0.0 for i in range(n)] for j in range(n)]
#       3     for t in test:
# ----> 4         c = classifier(t['vector'])
#       5         cnt[t['class']][c] += 1.0
#       6     return fMeasure(cnt, n)
#
# <ipython-input-411-3d19eb4ee97e> in <lambda>(v)
#       4         dist = allDistances[distName]
#       5
# ----> 6         f = lambda h: testAlgo(test, n, lambda v: kNN(v, n, train, h, kernel, dist))
#       7         res, bestH, f = gridSearch(f, 0.01, 2.0, 0.05)
#       8
#
# <ipython-input-404-90e71ad2513d> in kNN(newVector, n, objects, h, kernel, dist)
#       4         c = obj['class']
#       5         v = obj['vector']
# ----> 6         votes[c] += kernel(dist(newVector, v) / h)
#       7     return np.argmax(votes)
#
# <ipython-input-396-26b4e5a26fa4> in logistic(x)
#       1 def logistic(x):
#       2     print(x)
# ----> 3     return 1 / (math.exp(x) + 2.0 + math.exp(-x))
#
# OverflowError: math range error
